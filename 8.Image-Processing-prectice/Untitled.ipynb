# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
pic = Image.open('C:/Users/Admin/Desktop/Deep Learning/8.Image-Processing-prectice/DATA/00-puppy.jpg')

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)

# %%
pic_arr.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()

# %%
plt.imshow(pic_red)

# %%
# R G B
plt.imshow(pic_red[:,:,1],cmap = 'gray')

# %%
arr = np.random.randint(low=0,high=100,size=(5,5))

# %%
arr
# Out:
# array([[67, 96, 57,  9, 73],
#        [28, 75, 89, 20, 38],
#        [54, 46, 11, 67, 13],
#        [78, 14, 49, 60, 19],
#        [44, 86, 17, 52, 51]])

# %%
arr = np.ones((5,5))

# %%
import matplotlib.pyplot as plt

# %%
# R G B

# %%
pic_red[:,:,0] = 0

# %%
plt.imshow(pic_red)

# %%
pic_red[:,:,1]=0

# %%
plt.imshow(pic_red)

# %%
import cv2

# %%
img  = cv2.imread('C:/Users/Admin/Desktop/Deep Learning/8.Image-Processing-prectice/DATA/00-puppy.jpg')

# %%
img1 = cv2.imread('wrong/path') # if we dont provide correct path it will not generate error

# %%
plt.imshow(img)  # Reason why img is blue
#Matplotlib has order : R,G,B
# opencv has : B,G,R

# %%
fix_image = cv2.cvtColor(img , cv2.COLOR_BGR2RGB) # Convert BGR to RGB

# %%
plt.imshow(fix_image)

# %%
img_gray = cv2.imread('C:/Users/Admin/Desktop/Deep Learning/8.Image-Processing-prectice/DATA/00-puppy.jpg' , cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray,cmap = 'gray')

# %%
# Resize image
pic_red.shape
new_img = cv2.resize(pic_red,(400,400)) # Resize by Dimension
plt.imshow(new_img)

# %%
w_ratio = 0.5
h_ratio = 0.5
new_resized_image = cv2.resize(pic_red,(0,0),pic_red,w_ratio,h_ratio)

# %%
new_resized_image.shape
# Out:
# (650, 975, 3)

# %%
plt.imshow(new_resized_image)

# %%
print(new_resized_image.size)
print(pic_red.size)
# Out:
# 1901250
# 7605000

# %%
# Flip image
flipped_image = cv2.flip(pic_red,-1) # 0 : Horizontally |1 : Vertically |-1 : both
plt.imshow(flipped_image)

# %%
cv2.imwrite('my_image.jpg',flipped_image)
# Out:
# True

# %%
plt.imshow(img, cv2.COLOR_BGR2HSV)  # Prectice of HSV and HSL
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-822222ba2458> in <module>
# ----> 1 plt.imshow(img, cv2.COLOR_BGR2HSV)  # Prectice of HSV and HSL
#
# c:\users\admin\appdata\local\programs\python\python36\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2699         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2700         resample=resample, url=url, **({"data": data} if data is not
# -> 2701         None else {}), **kwargs)
#    2702     sci(__ret)
#    2703     return __ret
#
# c:\users\admin\appdata\local\programs\python\python36\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
# ...

# %%
# Image blendi and pesting
import cv2
import matplotlib.pyplot as plt
img1 = cv2.imread('C:/Users/Admin/Desktop/Deep Learning/8.Image-Processing-prectice/DATA/dog_backpack.png')
img1 = cv2.cvtColor(img1 ,cv2.COLOR_BGR2RGB)

img2 = cv2.imread('C:/Users/Admin/Desktop/Deep Learning/8.Image-Processing-prectice/DATA/watermark_no_copy.png')
img2 = cv2.cvtColor(img2 ,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img2)

# %%
img1 = cv2.resize(img1,(1200,1200))
img2 = cv2.resize(img2,(1200,1200))

# %%
blended = cv2.addWeighted(src1 =img1,alpha =0.8,src2 = img2,beta =0.1,gamma=0)

# %%
plt.imshow(blended)

# %%
 # Overlay small image on top of large image  
img1 = cv2.imread('C:/Users/Admin/Desktop/Deep Learning/8.Image-Processing-prectice/DATA/dog_backpack.png')
img1 = cv2.cvtColor(img1 ,cv2.COLOR_BGR2RGB)

img2 = cv2.imread('C:/Users/Admin/Desktop/Deep Learning/8.Image-Processing-prectice/DATA/watermark_no_copy.png')
img2 = cv2.cvtColor(img2 ,cv2.COLOR_BGR2RGB)
img2 = cv2.resize(img2,(600,600))

# %%
large_image = img1
small_image = img2
x_offset = 0
y_offset = 0
x_end = x_offset + small_image.shape[1]
y_end = y_offset + small_image.shape[0]

# %%
large_image[y_offset:y_end,x_offset:x_end] = small_image

# %%
plt.imshow(large_image)

# %%
img1.shape
# Out:
# (1401, 934, 3)

# %%
img2gray = cv2.cvtColor(img2 , cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(img2gray ,cmap ='gray')

# %%
mask_inv = cv2.bitwise_not(img2)

# %%
plt.imshow(mask_inv , cmap = 'gray')

# %%
 white_background = np.full(img2.shape ,255 ,dtype = np.uint8)

# %%
# white_background
bk = cv2.bitwise_or(white_background, white_background,mask = mask_inv)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-56-7e6e1bebac4d> in <module>
#       1 # white_background
# ----> 2 bk = cv2.bitwise_or(white_background, white_background,mask = mask_inv)
#
# error: OpenCV(4.0.0) C:\projects\opencv-python\opencv\modules\core\src\arithm.cpp:245: error: (-215:Assertion failed) (mtype == CV_8U || mtype == CV_8S) && _mask.sameSize(*psrc1) in function 'cv::binary_op'

# %%
# Thresholding
#(1) binary thresholding
#(2) adaptive thresholding
#(3) adaptive gaussian thresholding

# %%
# Videos
import cv2
cap =cv2.VideoCapture(0)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
writer = cv2.VideoWriter('abc.mp4',cv2.VideoWriter_fourcc(),20,(width,height))
while True:
    ret,frame = cap.read
    writer.write(frame)
    gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    cv2.imshow('frame',gray)
    if(cv2.waitKey(1) & 0xFF == ord('q')):
        break
cap.release()
writer.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-de3bb6b947e9> in <module>
#       4 width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
#       5 height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
# ----> 6 writer = cv2.VideoWriter('abc.mp4',cv2.VideoWriter_fourcc(),20,(width,height))
#       7 while True:
#       8     ret,frame = cap.read
#
# TypeError: Required argument 'c1' (pos 1) not found
